# %% [markdown]
# # What's in an Avocado Toast: A Supply Chain Analysis
#
# ![](avocado_wallpaper.jpeg)
#
# You find yourself in London, crafting a delectable avocado toast, a dish that has risen dramatically in popularity on breakfast menus since the 2010s. This straightforward recipe requires just five ingredients: a ripe avocado, half a lemon, a generous pinch of salt flakes, two slices of sourdough bread, and a good drizzle of extra virgin olive oil. Most of these ingredients are now staples in grocery stores, and as you will find with this project, that is no small feat!
#
# In this project, you'll conduct a supply chain analysis of three ingredients used in avocado toast using the Open Food Facts database. This database contains extensive, openly-sourced information on various foods, including their origins. Through this analysis, you will gain an in-depth understanding of the complex supply chain involved in producing a single dish.
#
# Three pairs of files are provided in the data folder:
# - A CSV file for each ingredient, such as `avocado.csv`, with data about each food item and countries of origin.
# - A TXT file for each ingredient, such as `relevant_avocado_categories`, containing only the category tags of interest for that food.
#
# Here are some other key points about these files:
# - Some of the rows of data in each of the three CSV files do not contain relevant data for your investigation. In each dataset, you will need to filter out rows with irrelevant data, based on values in the `categories_tags` column. Examples of categories are fruits, vegetables, and fruit-based oils. Filter the DataFrame to include only rows where `categories_tags` contains one of the tags in the relevant categories for that ingredient.
# - Each row of data usually has multiple category tags in the `categories_tags` column.
# There is a column in each CSV file called `origins_tags`, which contains strings for the country of origin of each item.
#
# After completing this project, you'll be armed with a list of ingredients and their countries of origin and be well-positioned to launch into other analyses that explore how long, on average, these ingredients spend at sea.
#
# [Open Food Facts database](https://world.openfoodfacts.org/)

# %%
import pandas as pd

# %%
#import the ingredients from the csvs
avocado = pd.read_csv('data/avocado.csv', sep='\t')
olive_oil = pd.read_csv('data/olive_oil.csv', sep='\t')
sourdough = pd.read_csv('data/sourdough.csv', sep='\t')

# %%
relevant_columns = ['code', 'lc', 'product_name_en', 'quantity', 'serving_size', 'packaging_tags','brands', 'brands_tags', 'categories_tags', 'labels_tags','countries', 'countries_tags', 'origins', 'origins_tags']

# %%
avocado = avocado[relevant_columns]
olive_oil = olive_oil[relevant_columns]
sourdough = sourdough[relevant_columns]

# %%
#drop rows where categories is empty
avocado = avocado[avocado['categories_tags'].isnull()==False]
sourdough = sourdough[sourdough['categories_tags'].isnull()==False]
olive_oil = olive_oil[olive_oil['categories_tags'].isnull()==False]

# %%
avocado = avocado[(avocado['countries'] == 'United Kingdom')]
sourdough = sourdough[(sourdough['countries'] == 'United Kingdom')]
olive_oil = olive_oil[(olive_oil['countries'] == 'United Kingdom')]

# %%
avocado['categories_tags']=avocado['categories_tags'].str.split(',')

# %%
sourdough.head(2)
# Out:
#              code  lc  ... origins origins_tags
# 20  5057172731138  en  ...     NaN          NaN
# 25  5059697263682  en  ...     NaN          NaN
#
# [2 rows x 14 columns]

# %%
avocado['categories_tags'].head(2)
# Out:
# 217    [en:plant-based-foods-and-beverages, en:plant-...
# 218    [en:plant-based-foods-and-beverages, en:plant-...
# Name: categories_tags, dtype: object

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 217 to 1771
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   code             26 non-null     object
#  1   lc               26 non-null     object
#  2   product_name_en  26 non-null     object
#  3   quantity         10 non-null     object
#  4   serving_size     3 non-null      object
#  5   packaging_tags   11 non-null     object
#  6   brands           20 non-null     object
#  7   brands_tags      20 non-null     object
#  8   categories_tags  26 non-null     object
#  9   labels_tags      7 non-null      object
#  10  countries        26 non-null     object
#  11  countries_tags   26 non-null     object
#  12  origins          5 non-null      object
#  13  origins_tags     5 non-null      object
# dtypes: object(14)
# memory usage: 3.0+ KB

# %%
avocado_categories = pd.read_csv('data/relevant_avocado_categories.txt', delimiter='\t')
olive_oil_categories = pd.read_csv('data/relevant_olive_oil_categories.txt', delimiter='\t')
sourdough_categories = pd.read_csv('data/relevant_sourdough_categories.txt', delimiter='\t')

# %%
avocado['origins_tags'] = avocado['origins_tags'].str.split(":", n=1).str[-1].str.strip()
sourdough['origins_tags'] = sourdough['origins_tags'].str.split(":", n=1).str[-1].str.strip()
olive_oil['origins_tags'] = olive_oil['origins_tags'].str.split(":", n=1).str[-1].str.strip()

# %%
top_avocado_origin = avocado.groupby('origins_tags').count().sort_values('code', ascending=False).index[0]

# %%
sourdough['origins_tags'] = sourdough['origins_tags'].str.replace("-", " ")

# %%
top_sourdough_origin = sourdough.groupby('origins_tags').count().sort_values('code', ascending=False).index[0]

# %%
top_olive_oil_origin = olive_oil.groupby('origins_tags').count().sort_values('code', ascending=False).index[0]

# %%
print(f"Most common country of origin for avocado: {top_avocado_origin}")
print(f"Most common country of origin for sourdough: {top_sourdough_origin}")
print(f"Most common country of origin for Olive oil: {top_olive_oil_origin}")
# Out:
# Most common country of origin for avocado: peru
# Most common country of origin for sourdough: united kingdom
# Most common country of origin for Olive oil: greece
